# %% [markdown]
# # Chapter 1 Homework: Agentic System Audit
#
# **Student Name**: [YOUR NAME HERE]
#
# **Email**: [YOUR EMAIL]
#
# **Date**: [SUBMISSION DATE]
#
# ---
#
# ## Instructions
#
# Complete all sections below. Use markdown cells for explanations and code cells for demonstrations/evidence.
#
# **Total time estimate**: 3-4 hours
#
# **Grading criteria**:
# - Depth of analysis (40%)
# - Evidence quality (30%)
# - Remediation realism (20%)
# - Presentation clarity (10%)
#
# ---

# %% [markdown]
# ## Section 1: System Description (200-300 words)
#
# **Which option are you choosing?**
#
# - [ ] Option A: My own agentic system
# - [ ] Option B: Provided case study (E-Commerce Order Processing)
# - [ ] Option C: Hypothetical system I designed
#
# ### System Overview
#
# [Replace this text with your system description. Include:]
#
# **Purpose**: What does the system do?
#
# [Your answer here]
#
# **Architecture**: How many agents? What are their roles?
#
# [Your answer here]
#
# **Technology**: Which LLM(s)? What framework (LangChain, custom, etc.)?
#
# [Your answer here]
#
# **Status**: Production or experimental? How long deployed? Usage volume?
#
# [Your answer here]
#
# **Observed Issues**: What prompted this audit?
#
# [Your answer here]

# %% [markdown]
# ---
#
# ## Section 2: Failure Mode 1
#
# ### 2.1 Failure Mode Identification
#
# **Which failure mode are you analyzing?**
#
# - [ ] Temporal coordination failure
# - [ ] Cost explosion
# - [ ] Prompt brittleness
# - [ ] Multi-agent coordination breakdown
#
# **Brief description of the failure**:
#
# [Describe what goes wrong, when it happens, and what the symptoms are]
#
# ### 2.2 Evidence Collection
#
# **Reproduce the failure below. Include**:
# - Exact inputs that trigger the failure
# - Observed outputs
# - Expected vs actual behavior
# - Measurements (accuracy, cost, latency, etc.)

# %%
# Setup (if needed)
# !pip install -q langchain langchain-anthropic anthropic

# Your evidence collection code here

# %% [markdown]
# **Evidence summary**:
#
# [Summarize what the evidence shows. Include quantitative measurements where possible.]
#
# ### 2.3 Root Cause Analysis
#
# **Apply the diagnosis decision tree from Chapter 1, Section 6**:
#
# 1. What type of failure is this?
#    - [ ] Performance degradation → [identify sub-cause]
#    - [ ] Cost explosion → [identify sub-cause]
#    - [ ] Coordination failure → [identify sub-cause]
#
# 2. What is the root cause?
#
# [Your analysis here. Be specific: is this pattern matching failure? Missing constraint check? Architectural limitation? Provide reasoning.]
#
# 3. Is this an architectural or implementation issue?
#
# [Your assessment: Can this be fixed with better prompts/code? Or does it require fundamental redesign?]
#
# ### 2.4 Remediation Proposal
#
# **Immediate mitigation** (if possible):
#
# [What can be done right now to reduce impact? Be specific and practical.]
#
# **Long-term solution**:
#
# [What is the proper fix? Which chapter's techniques would you use (Chapter 2: monitoring, Chapter 3: crystallization, Chapter 4: hybrid architecture)?]
#
# **Implementation effort estimate**:
#
# - Hours of work: [estimate]
# - Required skills: [list]
# - Dependencies: [what else needs to be in place?]

# %% [markdown]
# ---
#
# ## Section 3: Failure Mode 2
#
# ### 3.1 Failure Mode Identification
#
# **Which failure mode are you analyzing?**
#
# - [ ] Temporal coordination failure
# - [ ] Cost explosion
# - [ ] Prompt brittleness
# - [ ] Multi-agent coordination breakdown
#
# **Brief description of the failure**:
#
# [Describe what goes wrong]
#
# ### 3.2 Evidence Collection

# %%
# Your evidence collection code here

# %% [markdown]
# **Evidence summary**:
#
# [Summarize findings]
#
# ### 3.3 Root Cause Analysis
#
# **Apply the diagnosis decision tree**:
#
# 1. Failure type: [classification]
# 2. Root cause: [analysis]
# 3. Architectural vs implementation: [assessment]
#
# ### 3.4 Remediation Proposal
#
# **Immediate mitigation**: [describe]
#
# **Long-term solution**: [describe]
#
# **Implementation effort**: [estimate]

# %% [markdown]
# ---
#
# ## Section 4: Failure Mode 3 (Optional)
#
# **If you analyzed a third failure mode, document it here using the same structure as Sections 2 and 3.**
#
# Otherwise, delete this section.

# %% [markdown]
# ---
#
# ## Section 5: Reflection
#
# ### 5.1 Key Insights
#
# **What did you learn from this audit?**
#
# [Reflect on insights gained. What surprised you? What confirmed your suspicions?]
#
# ### 5.2 Patterns Across Failure Modes
#
# **Did you notice common patterns across the failures you analyzed?**
#
# [Are failures related? Do they share root causes? Would fixing one help with others?]
#
# ### 5.3 Next Steps
#
# **What would you prioritize fixing first, and why?**
#
# [Rank remediation priorities. Consider impact, effort, and dependencies.]
#
# ### 5.4 Questions for Future Chapters
#
# **What do you hope to learn in Chapters 2-4 to address these issues?**
#
# [List specific questions or topics you're interested in exploring]

# %% [markdown]
# ---
#
# ## Section 6: Submission Checklist
#
# Before submitting, verify:
#
# - [ ] Name and contact info at top of notebook
# - [ ] System description complete (200-300 words)
# - [ ] At least 2 failure modes analyzed
# - [ ] Evidence provided for each failure mode
# - [ ] Root cause analysis uses Chapter 1 framework
# - [ ] Remediation proposals are specific and actionable
# - [ ] Reflection section completed
# - [ ] All code cells run without errors (if code included)
# - [ ] File named: `chapter1_homework_[YOUR_NAME].ipynb`
#
# **Ready to submit!**
#
# Send to: javier@jmarin.info
#
# Subject: "Chapter 1 Homework - [YOUR NAME]"
#
# ---
#
# **End of Homework**
